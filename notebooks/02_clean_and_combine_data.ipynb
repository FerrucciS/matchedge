# %%
import pandas as pd
from rapidfuzz import process, fuzz
from clean_data import clean_results_df, clean_stats_df, update_player_listings, clean_rankings, clean_tournaments 
import numpy as np

# %% [markdown]
# ## Clean DataFrames

# %%
df_top = pd.read_csv("s3://matchedge-pipeline/data/raw/top_500_players_23_June.csv")
df_all_tournament = pd.read_csv("s3://matchedge-pipeline/data/raw/All_Tournaments.csv", sep=',')
df_results = pd.read_csv('s3://matchedge-pipeline/data/raw/all_results.csv')

# %%
df_top = clean_rankings(df_top)
df_all_tournament = clean_tournaments(df_all_tournament)
df_results = clean_results_df(df_results)

# %% [markdown]
# Save as csv

# %%
df_top.to_csv('/Users/samueleferrucci/Documents/Coding/Projects/Tennis ML/data/clean/top_500_players.csv', sep=",", columns=df_top.columns, index=False)
df_top.to_csv("s3://matchedge-pipeline/data/clean/top_500_players.csv", sep=",", columns=df_top.columns, index=False)


df_all_tournament.to_csv('/Users/samueleferrucci/Documents/Coding/Projects/Tennis ML/data/clean/all_tournaments.csv', sep=',', columns=df_all_tournament.columns, index=False)
df_all_tournament.to_csv('s3://matchedge-pipeline/data/clean/all_tournaments.csv', sep=',', columns=df_all_tournament.columns, index=False)

df_results.to_csv('/Users/samueleferrucci/Documents/Coding/Projects/Tennis ML/data/clean/all_results.csv', sep=',', columns=df_results.columns, index=False)
df_results.to_csv('s3://matchedge-pipeline/data/clean/all_results.csv', sep=',', columns=df_results.columns, index=False)

# %% [markdown]
# ---
# ## Clean Stat Data

# %%
df_all_stats = pd.read_csv('s3://matchedge-pipeline/data/raw/all_stats_GS.csv', sep=',')

# %%
df_all_stats = clean_stats_df(df_all_stats)

# %% [markdown]
# Save as csv

# %%
df_all_stats.to_csv('/Users/samueleferrucci/Documents/Coding/Projects/Tennis ML/data/clean/all_stats.csv', sep=',', columns=df_all_stats.columns, index=False)
df_all_stats.to_csv("s3://matchedge-pipeline/data/clean/all_stats.csv", sep=',', columns=df_all_stats.columns, index=False)

# %% [markdown]
# ---
# ---
# ## Create First Player Listing (Do Only Once With Cleaning)

# %%
listing = update_player_listings()

# %%
listing.to_csv("s3://matchedge-pipeline/data/clean/player_archive.csv", columns=listing.columns, sep=',')
listing.to_csv("/Users/samueleferrucci/Documents/Coding/Projects/Tennis ML/data/clean/player_archive.csv", columns=listing.columns, sep=',')

# %% [markdown]
# ### Moving Forward Notes
#
# Run ```update_player_listings()``` after scraping so can use ```player_archive.csv``` to clean results and stats. Call it with ```update_player_listings(df_live_rankings=df_top_scraped, df_results = df_results_scraped, df_stats = df_stats_scraped)```

# %% [markdown]
# ---
# ---
# ## Combine Relevant Data Into One Table

# %%
results_414 = df_results[df_results['tournament_id']==414]
tournament_414 = df_all_tournament[df_all_tournament['id']==414]

other_results = df_results[df_results['tournament_id'] != 414]
other_tournaments = df_all_tournament[df_all_tournament['id'] != 414]

merged_tourn_results_414 = pd.merge(
    results_414, tournament_414[['id', 'level', 'location', 'surface', 'year']],
    left_on=['tournament_id', 'year'],
    right_on=['id', 'year'],
    how='left'
)

other_merged_results = pd.merge(
    other_results, other_tournaments[['id', 'level', 'location', 'surface']],
    left_on=["tournament_id"],
    right_on=["id"],
    how="left"
)

merged_tourn_results_414 = merged_tourn_results_414.drop(columns=["id"])
other_merged_results = other_merged_results.drop(columns=["id"])

merged_tourn_result_trial = pd.concat([merged_tourn_results_414, other_merged_results], ignore_index=True)

# %%
df_all_stats_trial = df_all_stats.copy()

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### Match p1,p1 in Stats and Results Tables

# %%
i = 0

p1_cols = ['player_1', 'player_1_scores', 'p1_id', 'p1_set1', 'p1_set2', 'p1_set3', 'p1_set4', 'p1_set5']
p2_cols = ['player_2', 'player_2_scores', 'p2_id', 'p2_set1', 'p2_set2', 'p2_set3', 'p2_set4', 'p2_set5']

valid_pairs1 = set(zip(df_all_stats_trial['tournament_id'], df_all_stats_trial['match_id']))
valid_pairs2 = set(zip(df_all_stats_trial['tournament_id'], df_all_stats_trial['match_id'], df_all_stats_trial['p1_id']))
valid_pairs3 = set(zip(df_all_stats_trial['tournament_id'], df_all_stats_trial['match_id'], df_all_stats_trial['p2_id']))
valid_pairs4 = set(zip(df_all_stats_trial['tournament_id'], df_all_stats_trial['p1_id'], df_all_stats_trial['p2_id']))


def reorder_players(row):
    global i
    tid, mid = row['tournament_id'], row['match_id']
    p1_id, p2_id = row['p1_id'], row['p2_id']
    
    orig_pair1 = (tid, mid)
    pair2_p1 = (tid, mid, p1_id)
    pair2_p2 = (tid, mid, p2_id)
    pair_no_match = (tid, p1_id, p2_id)
    swapped_no_match = (tid, p2_id, p1_id)
    
    ########################################################################################################################
    # Special case for tournament 414
    if tid == 414:
        if pair_no_match in valid_pairs4:
            return row
        elif swapped_no_match in valid_pairs4:
            for c1, c2 in zip(p1_cols, p2_cols):
                row[c1], row[c2] = row[c2], row[c1]
            return row
        else:
            print(f"[FAIL: 414 special case] tournament_id=414, p1_id={p1_id}, p2_id={p2_id}")
            return row
    ########################################################################################################################

    if pd.notna(mid) and orig_pair1 in valid_pairs1:
        if pair2_p1 in valid_pairs2 or pair2_p2 in valid_pairs3:
            return row
        elif pair2_p1 in valid_pairs3 or pair2_p2 in valid_pairs2:
            for c1, c2 in zip(p1_cols, p2_cols):
                row[c1], row[c2] = row[c2], row[c1]
            return row
        else:
            print(f"[FAIL: valid match_id, but player ID mismatch] match_id={mid}, tournament_id={tid}, p1_id={p1_id}, p2_id={p2_id}")
            return row
    elif pd.isna(mid):
        if pair_no_match in valid_pairs4:
            return row
        elif swapped_no_match in valid_pairs4:
            for c1, c2 in zip(p1_cols, p2_cols):
                row[c1], row[c2] = row[c2], row[c1]
            return row
        else:
            print(f"[FAIL: missing match_id, and player ID pair not found] tournament_id={tid}, p1_id={p1_id}, p2_id={p2_id}")
            return row
    else:
        print(f"[FAIL: match_id not in valid_pairs1] match_id={mid}, tournament_id={tid}")
        return row

# %%
merged_tourn_result_trial = merged_tourn_result_trial.apply(reorder_players, axis=1)
# Out:
# [FAIL: 414 special case] tournament_id=414, p1_id=m0gz, p2_id=bk92
# [FAIL: 414 special case] tournament_id=414, p1_id=sg56, p2_id=<NA>
# [FAIL: 414 special case] tournament_id=414, p1_id=f0f1, p2_id=r0dg
# [FAIL: 414 special case] tournament_id=414, p1_id=ta29, p2_id=o513
# [FAIL: 414 special case] tournament_id=414, p1_id=d0c1, p2_id=<NA>
# [FAIL: 414 special case] tournament_id=414, p1_id=mw75, p2_id=ss25
# [FAIL: match_id not in valid_pairs1] match_id=qs024, tournament_id=339
# [FAIL: match_id not in valid_pairs1] match_id=qs025, tournament_id=339
# [FAIL: match_id not in valid_pairs1] match_id=qs027, tournament_id=339
# [FAIL: match_id not in valid_pairs1] match_id=ms023, tournament_id=8998
# [FAIL: match_id not in valid_pairs1] match_id=ms023, tournament_id=301
# [FAIL: match_id not in valid_pairs1] match_id=ms008, tournament_id=580
# [FAIL: match_id not in valid_pairs1] match_id=ms009, tournament_id=580
# [FAIL: match_id not in valid_pairs1] match_id=ms010, tournament_id=580
# [FAIL: match_id not in valid_pairs1] match_id=ms011, tournament_id=580
# [FAIL: match_id not in valid_pairs1] match_id=ms054, tournament_id=580
# [FAIL: match_id not in valid_pairs1] match_id=qs008, tournament_id=375
# [FAIL: match_id not in valid_pairs1] match_id=ms008, tournament_id=424
# [FAIL: match_id not in valid_pairs1] match_id=qs004, tournament_id=424
# [FAIL: match_id not in valid_pairs1] match_id=ms004, tournament_id=407
# [FAIL: match_id not in valid_pairs1] match_id=ms014, tournament_id=407
# [FAIL: match_id not in valid_pairs1] match_id=qs013, tournament_id=407
# [FAIL: match_id not in valid_pairs1] match_id=qs004, tournament_id=496
# [FAIL: match_id not in valid_pairs1] match_id=ms008, tournament_id=6932
# [FAIL: match_id not in valid_pairs1] match_id=ms018, tournament_id=6932
# [FAIL: match_id not in valid_pairs1] match_id=qs015, tournament_id=6932
# [FAIL: match_id not in valid_pairs1] match_id=qs009, tournament_id=6932
# [FAIL: match_id not in valid_pairs1] match_id=ms005, tournament_id=495
# [FAIL: match_id not in valid_pairs1] match_id=ms058, tournament_id=403
# [FAIL: match_id not in valid_pairs1] match_id=ms014, tournament_id=717
# [FAIL: match_id not in valid_pairs1] match_id=ms022, tournament_id=360
# [FAIL: match_id not in valid_pairs1] match_id=ms036, tournament_id=410
# [FAIL: match_id not in valid_pairs1] match_id=ms044, tournament_id=410
# [FAIL: match_id not in valid_pairs1] match_id=ms001, tournament_id=425
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=1536
# [FAIL: match_id not in valid_pairs1] match_id=ms101, tournament_id=1536
# [FAIL: match_id not in valid_pairs1] match_id=ms016, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=ms104, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=qs026, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=qs053, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=qs065, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=qs094, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=qs113, tournament_id=520
# [FAIL: match_id not in valid_pairs1] match_id=qs007, tournament_id=321
# [FAIL: match_id not in valid_pairs1] match_id=ms020, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=ms028, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=ms023, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=ms022, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=ms026, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=qs006, tournament_id=311
# [FAIL: match_id not in valid_pairs1] match_id=ms023, tournament_id=500
# [FAIL: match_id not in valid_pairs1] match_id=ms027, tournament_id=500
# [FAIL: match_id not in valid_pairs1] match_id=ms017, tournament_id=500
# [FAIL: match_id not in valid_pairs1] match_id=ms026, tournament_id=500
# [FAIL: match_id not in valid_pairs1] match_id=ms018, tournament_id=500
# [FAIL: match_id not in valid_pairs1] match_id=ms025, tournament_id=500
# [FAIL: match_id not in valid_pairs1] match_id=ms014, tournament_id=540
# [FAIL: match_id not in valid_pairs1] match_id=ms059, tournament_id=540
# [FAIL: match_id not in valid_pairs1] match_id=ms041, tournament_id=540
# [FAIL: match_id not in valid_pairs1] match_id=ms076, tournament_id=540
# [FAIL: match_id not in valid_pairs1] match_id=qs015, tournament_id=315
# [FAIL: match_id not in valid_pairs1] match_id=ms030, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=ms025, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=ms026, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=ms022, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=ms017, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=qs005, tournament_id=316
# [FAIL: match_id not in valid_pairs1] match_id=ms018, tournament_id=314
# [FAIL: match_id not in valid_pairs1] match_id=qs014, tournament_id=314
# [FAIL: valid match_id, but player ID mismatch] match_id=qs010, tournament_id=439, p1_id=<NA>, p2_id=<NA>
# [FAIL: match_id not in valid_pairs1] match_id=ms030, tournament_id=6116
# [FAIL: match_id not in valid_pairs1] match_id=qs009, tournament_id=6116
# [FAIL: match_id not in valid_pairs1] match_id=ms008, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms009, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms012, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms011, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms013, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms014, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms019, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms024, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms030, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms026, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms029, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=319
# [FAIL: match_id not in valid_pairs1] match_id=ms007, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms010, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms013, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms016, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms031, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms027, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms028, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms023, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms024, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms025, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms029, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms049, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms046, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=qs027, tournament_id=418
# [FAIL: match_id not in valid_pairs1] match_id=ms010, tournament_id=421
# [FAIL: match_id not in valid_pairs1] match_id=ms018, tournament_id=421
# [FAIL: match_id not in valid_pairs1] match_id=ms058, tournament_id=421
# [FAIL: match_id not in valid_pairs1] match_id=ms006, tournament_id=422
# [FAIL: match_id not in valid_pairs1] match_id=ms025, tournament_id=422
# [FAIL: match_id not in valid_pairs1] match_id=ms033, tournament_id=422
# [FAIL: match_id not in valid_pairs1] match_id=qs022, tournament_id=422
# [FAIL: match_id not in valid_pairs1] match_id=ms003, tournament_id=6242
# [FAIL: valid match_id, but player ID mismatch] match_id=qs004, tournament_id=6242, p1_id=<NA>, p2_id=<NA>
# [FAIL: match_id not in valid_pairs1] match_id=qs014, tournament_id=6242
# [FAIL: valid match_id, but player ID mismatch] match_id=qs009, tournament_id=6242, p1_id=<NA>, p2_id=<NA>
# [FAIL: valid match_id, but player ID mismatch] match_id=qs008, tournament_id=6242, p1_id=<NA>, p2_id=<NA>
# [FAIL: match_id not in valid_pairs1] match_id=ms026, tournament_id=560
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=4713
# [FAIL: match_id not in valid_pairs1] match_id=ms008, tournament_id=329
# [FAIL: match_id not in valid_pairs1] match_id=qs040, tournament_id=5014
# [FAIL: match_id not in valid_pairs1] match_id=qs011, tournament_id=9410
# [FAIL: match_id not in valid_pairs1] match_id=ms003, tournament_id=7485
# [FAIL: match_id not in valid_pairs1] match_id=ms030, tournament_id=7485
# [FAIL: match_id not in valid_pairs1] match_id=ms012, tournament_id=429
# [FAIL: match_id not in valid_pairs1] match_id=qs006, tournament_id=429
# [FAIL: match_id not in valid_pairs1] match_id=ms015, tournament_id=337
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=328
# [FAIL: match_id not in valid_pairs1] match_id=ms012, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=ms021, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=ms060, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=ms062, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=ms050, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=qs012, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=qs025, tournament_id=352
# [FAIL: match_id not in valid_pairs1] match_id=ms006, tournament_id=4787
# [FAIL: match_id not in valid_pairs1] match_id=ms017, tournament_id=4787
# [FAIL: match_id not in valid_pairs1] match_id=qs009, tournament_id=4787
# [FAIL: match_id not in valid_pairs1] match_id=ms009, tournament_id=341
# [FAIL: match_id not in valid_pairs1] match_id=ms018, tournament_id=341
# [FAIL: match_id not in valid_pairs1] match_id=qs005, tournament_id=341
# [FAIL: match_id not in valid_pairs1] match_id=ms016, tournament_id=7696

# %%
df_all_stats_trial[df_all_stats_trial['tournament_id']==414]['p1_id']
# Out:
# 1391    False
# 1392    False
# 1393    False
# 1394    False
# 1395    False
#         ...
# 1655    False
# 1656    False
# 1657    False
# 1658    False
# 1659    False
# Name: p1_id, Length: 82, dtype: bool

# %%
merged_tourn_result_trial[merged_tourn_result_trial['tournament_id']==414]['p1_id'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# Name: p1_id, Length: 86, dtype: bool

# %%
merge_keys = ['tournament_id', 'match_id', 'player_1', 'player_2']

merged_tourn_results_414 = merged_tourn_result_trial[merged_tourn_result_trial['tournament_id']==414]
stat_414 = df_all_stats_trial[df_all_stats_trial['tournament_id']==414]

merged_stats_414 = pd.merge(
    merged_tourn_results_414,
    stat_414, on=merge_keys,
    how='left'
)

# Drop all _y columns
merged_stats_414 = merged_stats_414.loc[:, ~merged_stats_414.columns.str.endswith('_y')]

# Rename _x columns (remove suffix)
merged_stats_414.columns = merged_stats_414.columns.str.replace('_x$', '', regex=True)

# %%
merge_keys = ['tournament_id', 'match_id']

merged_tourn_results_not_414 = merged_tourn_result_trial[merged_tourn_result_trial['tournament_id']!=414]
stat_not_414 = df_all_stats_trial[df_all_stats_trial['tournament_id']!=414]

merged_stats_not_414 = pd.merge(
    merged_tourn_results_not_414,
    stat_not_414, on=merge_keys,
    how='left'
)

# Drop all _y columns
merged_stats_not_414 = merged_stats_not_414.loc[:, ~merged_stats_not_414.columns.str.endswith('_y')]

# Rename _x columns (remove suffix)
merged_stats_not_414.columns = merged_stats_not_414.columns.str.replace('_x$', '', regex=True)

# %%
print(merged_stats_not_414.columns == merged_stats_414.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True]

# %%
merged_tourn_stat_trial = pd.concat([merged_stats_414, merged_stats_not_414], ignore_index=True)

# %%
cols = [
    "p1_first_serve", "p1_1st_serve_points_won", "p1_2nd_serve_points_won",
    "p1_1st_serve_return_points_won", "p1_service_points_won", "p1_2nd_serve_return_points_won",
    "p1_return_points_won", "p1_total_points_won",
    "p2_first_serve", "p2_1st_serve_points_won", "p2_2nd_serve_points_won",
    "p2_1st_serve_return_points_won", "p2_service_points_won", "p2_2nd_serve_return_points_won",
    "p2_return_points_won", "p2_total_points_won"
]

merged_tourn_stat_trial = merged_tourn_stat_trial.dropna(subset=cols, how='all')

# %%
merged_tourn_stat_trial
# Out:
#      match_date            player_1            player_2        duration  \
# 0    2025-05-24           A. Rublev          F. Cobolli 0 days 01:28:37
# 1    2025-05-23  F. Auger-Aliassime           A. Rublev 0 days 01:25:13
# 2    2025-05-23       T. Etcheverry          F. Cobolli 0 days 02:47:54
# 3    2025-05-22           A. Rublev          L. Darderi 0 days 01:53:35
# 4    2025-05-22           A. Muller  F. Auger-Aliassime 0 days 02:58:31
# ...         ...                 ...                 ...             ...
# 3833 2024-12-22            J. Shang      N. Basavareddy 0 days 01:33:00
# 3834 2024-12-22             A. Fils          J. Fonseca 0 days 01:50:00
# 3835 2024-12-22           J. Mensik             L. Tien 0 days 02:17:00
# 3836 2024-12-22        A. Michelsen      N. Basavareddy 0 days 01:53:00
# 3837 2024-12-22            J. Shang       L. Van Assche 0 days 01:56:00
#
#          match_round     player_1_scores player_2_scores  \
# 0              Final                 2 4             6 6
# 1        Semi-Finals                 1 4             6 6
# 2        Semi-Finals               6 5 4           2 7 6
# 3     Quarter-Finals               6 3 6           1 6 3
# 4     Quarter-Finals            6(4) 7 3        7 6(6) 6
# ...              ...                 ...             ...
# 3833   Round Robin -             4 2 2 1      3(4) 4 4 4
# 3834   Round Robin -           4 2 1 4 1    3(9) 4 4 1 4
# 3835   Round Robin -  3(6) 3(3) 4 4 3(8)       4 4 2 2 4
# 3836   Round Robin -             2 4 4 4   4 3(5) 3(4) 2
# 3837   Round Robin -       3(3) 4 1 3(5)         4 2 4 4
#
#                      winner     result match_id  ...  p2_service_points_won  \
# 0            Flavio Cobolli  Completed    ms001  ...                   0.61
# 1             Andrey Rublev  Completed    ms002  ...                   0.73
# 2            Flavio Cobolli  Completed    ms003  ...                   0.60
# 3             Andrey Rublev  Completed    ms005  ...                   0.61
# 4     Felix Auger-Aliassime  Completed    ms004  ...                   0.64
# ...                     ...        ...      ...  ...                    ...
# 3833    Nishesh Basavareddy  Completed    ms020  ...                   0.69
# 3834           Joao Fonseca  Completed    ms010  ...                   0.70
# 3835           Learner Tien  Completed    ms011  ...                   0.64
# 3836         Alex Michelsen  Completed    ms018  ...                   0.66
# 3837        Luca Van Assche  Completed    ms019  ...                   0.66
#
#      p2_return_points_won p2_total_points_won p2_max_speed  \
# 0                    0.50                0.57          NaN
# 1                    0.43                0.58          NaN
# 2                    0.38                0.49          NaN
# 3                    0.31                0.46          NaN
# 4                    0.38                0.51          NaN
# ...                   ...                 ...          ...
# 3833                 0.42                0.54          NaN
# 3834                 0.33                0.52          NaN
# 3835                 0.26                0.47          NaN
# 3836                 0.35                0.50          NaN
# 3837                 0.44                0.55          NaN
#
#       p2_1st_serve_average_speed p2_2nd_serve_average_speed  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 3833                         NaN                        NaN
# 3834                         NaN                        NaN
# 3835                         NaN                        NaN
# 3836                         NaN                        NaN
# 3837                         NaN                        NaN
#
#      p2_break_point_opportunities p1_break_point_opportunities  \
# 0                             4.0                          7.0
# 1                             7.0                          1.0
# 2                            10.0                          7.0
# 3                             6.0                          7.0
# 4                            12.0                          6.0
# ...                           ...                          ...
# 3833                         11.0                          6.0
# 3834                         11.0                          5.0
# 3835                          1.0                          9.0
# 3836                          5.0                          7.0
# 3837                         13.0                          4.0
#
#      p1_net_points_played  p2_net_points_played
# 0                     7.0                   5.0
# 1                     2.0                   8.0
# 2                    16.0                  10.0
# 3                    12.0                   4.0
# 4                    15.0                  21.0
# ...                   ...                   ...
# 3833                  4.0                   9.0
# 3834                  8.0                   9.0
# 3835                 22.0                   9.0
# 3836                 20.0                  16.0
# 3837                  8.0                   5.0
#
# [3704 rows x 78 columns]

# %% [markdown]
# This is good! there are only 4 missing rows that are available in ```df_all_stats_trial```.

# %% [markdown]
# ---
# ---

# %%
merged_tourn_stat_trial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3704 entries, 0 to 3837
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   match_date                      3704 non-null   datetime64[ns]
#  1   player_1                        3704 non-null   object
#  2   player_2                        3704 non-null   object
#  3   duration                        3242 non-null   timedelta64[ns]
#  4   match_round                     3704 non-null   object
#  5   player_1_scores                 3704 non-null   object
#  6   player_2_scores                 3704 non-null   object
#  7   winner                          3704 non-null   object
#  8   result                          3704 non-null   object
#  9   match_id                        3704 non-null   object
#  10  tournament_id                   3704 non-null   int64
#  11  stats_link                      3704 non-null   object
#  12  p1_id                           3668 non-null   object
#  13  p2_id                           3664 non-null   object
#  14  p1_set1                         3704 non-null   int64
#  15  p1_set2                         3674 non-null   object
#  16  p1_set3                         1657 non-null   object
#  17  p1_set4                         291 non-null    object
#  18  p1_set5                         116 non-null    object
#  19  p2_set1                         3704 non-null   int64
#  20  p2_set2                         3674 non-null   object
#  21  p2_set3                         1657 non-null   object
#  22  p2_set4                         291 non-null    object
#  23  p2_set5                         116 non-null    object
#  24  best_of                         3704 non-null   int64
#  25  winner_id                       3688 non-null   object
#  26  year                            3704 non-null   int64
#  27  level                           3704 non-null   object
#  28  location                        3704 non-null   object
#  29  surface                         3704 non-null   object
#  30  p1_serve_rating                 3704 non-null   float64
#  31  p1_aces                         3704 non-null   float64
#  32  p1_double_faults                3704 non-null   float64
#  33  p1_first_serve                  2771 non-null   float64
#  34  p1_1st_serve_points_won         3704 non-null   float64
#  35  p1_2nd_serve_points_won         3703 non-null   float64
#  36  p1_break_points_saved           3495 non-null   float64
#  37  p1_service_games_played         3704 non-null   float64
#  38  p1_return_rating                3704 non-null   float64
#  39  p1_1st_serve_return_points_won  3704 non-null   float64
#  40  p1_2nd_serve_return_points_won  3704 non-null   float64
#  41  p1_break_points_converted       3533 non-null   float64
#  42  p1_return_games_played          3704 non-null   float64
#  43  p1_net_points_won               2678 non-null   float64
#  44  p1_winners                      2692 non-null   float64
#  45  p1_unforced_errors              2692 non-null   float64
#  46  p1_service_points_won           3704 non-null   float64
#  47  p1_return_points_won            3704 non-null   float64
#  48  p1_total_points_won             3704 non-null   float64
#  49  p1_max_speed                    0 non-null      float64
#  50  p1_1st_serve_average_speed      0 non-null      float64
#  51  p1_2nd_serve_average_speed      0 non-null      float64
#  52  p2_serve_rating                 3704 non-null   float64
#  53  p2_aces                         3704 non-null   float64
#  54  p2_double_faults                3704 non-null   float64
#  55  p2_first_serve                  2771 non-null   float64
#  56  p2_1st_serve_points_won         3704 non-null   float64
#  57  p2_2nd_serve_points_won         3704 non-null   float64
#  58  p2_break_points_saved           3533 non-null   float64
#  59  p2_service_games_played         3704 non-null   float64
#  60  p2_return_rating                3704 non-null   float64
#  61  p2_1st_serve_return_points_won  3704 non-null   float64
#  62  p2_2nd_serve_return_points_won  3703 non-null   float64
#  63  p2_break_points_converted       3495 non-null   float64
#  64  p2_return_games_played          3704 non-null   float64
#  65  p2_net_points_won               2680 non-null   float64
#  66  p2_winners                      2692 non-null   float64
#  67  p2_unforced_errors              2692 non-null   float64
#  68  p2_service_points_won           3704 non-null   float64
#  69  p2_return_points_won            3704 non-null   float64
#  70  p2_total_points_won             3704 non-null   float64
#  71  p2_max_speed                    0 non-null      float64
#  72  p2_1st_serve_average_speed      0 non-null      float64
#  73  p2_2nd_serve_average_speed      0 non-null      float64
#  74  p2_break_point_opportunities    3704 non-null   float64
#  75  p1_break_point_opportunities    3704 non-null   float64
#  76  p1_net_points_played            3704 non-null   float64
#  77  p2_net_points_played            3704 non-null   float64
# dtypes: datetime64[ns](1), float64(48), int64(5), object(23), timedelta64[ns](1)
# memory usage: 2.2+ MB

# %%
merged_tourn_stat_trial[merged_tourn_stat_trial['p1_id'].isna()]
# Out:
#      match_date                player_1               player_2  \
# 250  2025-01-05          A. Klintcharov               S. Nagal
# 446  2025-01-07               C. Hewitt        N. Basilashvili
# 473  2025-01-06        T. van Rijthoven                 J. Kym
# 614  2025-02-01               N. Visker           A. Vavassori
# 811  2025-02-15  J. Lucas Reis Da Silva               C. Tseng
# 894  2025-02-22              R. De Alba              G. Diallo
# 933  2025-02-22     G. Alberto Olivieri               G. Heide
# 934  2025-02-22       A. Daniel Vallejo            J. Ficovich
# 1066 2025-03-03          T. Papamalamis           M. Kukushkin
# 1310 2025-03-30     S. Adrian Andreescu               R. Albot
# 1479 2025-04-12         M. Hans Rehberg   B. van de Zandschulp
# 1730 2025-05-05               P. Basile        T. Seyboth Wild
# 2003 2025-05-19        T. van Rijthoven  S. Gueymard Wayenburg
# 2091 2025-06-07           M. Rottgering                J. Sels
# 2175 2025-06-14           M. Schoenhaus             J. de Jong
# 2450 2024-07-21          T. Kwiatkowski             M. Krueger
# 2490 2024-07-21         L. Fredrik Hede            D. Yevseyev
# 2491 2024-07-21            A. Kuznetsov               J. Faria
# 2560 2024-07-27            G. Andreozzi               C. Tseng
# 2569 2024-07-27        D. Jorda Sanchis               N. Hardt
# 2570 2024-07-27            G. Andreozzi          N. Serdarusic
# 2862 2024-08-19         J. Floyd Angele            R. Hijikata
# 2913 2024-08-24          S. Kirchheimer         T. Kwiatkowski
# 2918 2024-08-24          T. Kwiatkowski            S. Mansouri
# 2921 2024-08-24          S. Kirchheimer            R. Fishback
# 3199 2024-09-24            E. Gerasimov                  L. Tu
# 3393 2024-10-13            E. Gerasimov              T. Daniel
# 3411 2024-10-13           R. Ramanathan          A. Shevchenko
# 3427 2024-10-13            E. Gerasimov          A. Moro Canas
# 3447 2024-10-13           R. Ramanathan            U. Blanchet
# 3491 2024-10-20           A. Omarkhanov               D. Evans
# 3513 2024-10-20        G. Arnaud Bailly            D. Altmaier
# 3524 2024-10-20        G. Arnaud Bailly        N. Basilashvili
# 3569 2024-10-20                 R. Ymer           K. Majchrzak
# 3571 2024-10-20              A. Reymond          H. Medjedovic
# 3769 2024-11-09           M. Maksimovic             T. Tirante
#
#             duration           match_round player_1_scores player_2_scores  \
# 250  0 days 01:54:40  1st Round Qualifying           6 3 1           1 6 6
# 446              NaT  1st Round Qualifying             1 4             6 6
# 473              NaT  1st Round Qualifying             0 3             6 6
# 614  0 days 01:22:04  1st Round Qualifying          6(2) 2             7 6
# 811  0 days 02:43:14  1st Round Qualifying           7 3 4        6(0) 6 6
# 894  0 days 01:13:07  1st Round Qualifying             1 1             6 6
# 933  0 days 01:12:40  1st Round Qualifying             2 2             6 6
# 934  0 days 01:24:05  1st Round Qualifying             2 3             6 6
# 1066 0 days 03:26:16  1st Round Qualifying           4 7 5        6 6(4) 7
# 1310 0 days 02:07:01  1st Round Qualifying           6 3 2           4 6 6
# 1479 0 days 01:09:42  1st Round Qualifying             3 1             6 6
# 1730 0 days 01:08:40  1st Round Qualifying             2 3             6 6
# 2003             NaT  1st Round Qualifying          6(4) 0             7 6
# 2091 0 days 01:10:07  1st Round Qualifying             6 6             4 2
# 2175 0 days 02:06:00  1st Round Qualifying           5 6 2           7 3 6
# 2450 0 days 01:39:00  1st Round Qualifying          3 6(4)             6 7
# 2490 0 days 01:24:00  1st Round Qualifying           6 1 1           2 6 6
# 2491 0 days 01:06:00  1st Round Qualifying             3 4             6 6
# 2560 0 days 01:43:00  2nd Round Qualifying             6 7             4 5
# 2569 0 days 03:17:00  1st Round Qualifying           7 5 7     6(3) 7 6(5)
# 2570 0 days 01:39:00  1st Round Qualifying             6 6             4 4
# 2862 0 days 00:54:00  1st Round Qualifying             1 1             6 6
# 2913 0 days 01:24:00  2nd Round Qualifying             6 6             3 4
# 2918 0 days 02:46:00  1st Round Qualifying           7 4 7     6(7) 6 6(5)
# 2921 0 days 01:26:00  1st Round Qualifying             6 7             1 5
# 3199 0 days 01:01:00  1st Round Qualifying             4 1             6 6
# 3393 0 days 02:15:00          Round of 128           7 3 4        6(5) 6 6
# 3411 0 days 01:13:00          Round of 128          1 6(3)             6 7
# 3427 0 days 02:59:00  2nd Round Qualifying        6(3) 6 7        7 3 6(6)
# 3447 0 days 02:07:00  1st Round Qualifying           6 4 6           4 6 4
# 3491 0 days 01:08:00  1st Round Qualifying             4 2             6 6
# 3513 0 days 01:17:00           Round of 32             4 3             6 6
# 3524 0 days 01:41:00  2nd Round Qualifying             7 6          6(4) 1
# 3569 0 days 00:49:00  1st Round Qualifying             1 1             6 6
# 3571 0 days 01:35:00  1st Round Qualifying          6(4) 5             7 7
# 3769 0 days 01:47:00  1st Round Qualifying          6(7) 3             7 6
#
#                          winner     result match_id  ...  \
# 250                 Sumit Nagal  Completed    qs009  ...
# 446        Nikoloz Basilashvili  Completed    qs082  ...
# 473                  Jerome Kym  Completed    qs115  ...
# 614            Andrea Vavassori  Completed    qs008  ...
# 811             Chun-Hsin Tseng  Completed    qs011  ...
# 894              Gabriel Diallo  Completed    qs009  ...
# 933               Gustavo Heide  Completed    qs011  ...
# 934         Juan Pablo Ficovich  Completed    qs013  ...
# 1066          Mikhail Kukushkin  Completed    qs051  ...
# 1310                 Radu Albot  Completed    qs015  ...
# 1479    Botic van de Zandschulp  Completed    qs011  ...
# 1730        Thiago Seyboth Wild  Completed    qs041  ...
# 2003  Sascha Gueymard Wayenburg  Completed    qs082  ...
# 2091            Mees Rottgering  Completed    qs009  ...
# 2175             Jesper de Jong  Completed    qs011  ...
# 2450           Mitchell Krueger  Completed    qs013  ...
# 2490             Denis Yevseyev  Completed    qs013  ...
# 2491                Jaime Faria  Completed    qs015  ...
# 2560            Guido Andreozzi  Completed    qs005  ...
# 2569        David Jorda Sanchis  Completed    qs009  ...
# 2570            Guido Andreozzi  Completed    qs010  ...
# 2862             Rinky Hijikata  Completed    qs019  ...
# 2913         Strong Kirchheimer  Completed    qs004  ...
# 2918       Thai-Son Kwiatkowski  Completed    qs009  ...
# 2921         Strong Kirchheimer  Completed    qs008  ...
# 3199                      Li Tu  Completed    qs011  ...
# 3393                Taro Daniel  Completed    ms065  ...
# 3411       Alexander Shevchenko  Completed    ms098  ...
# 3427             Egor Gerasimov  Completed    qs025  ...
# 3447        Ramkumar Ramanathan  Completed    qs039  ...
# 3491               Daniel Evans  Completed    qs009  ...
# 3513            Daniel Altmaier  Completed    ms029  ...
# 3524       Gilles Arnaud Bailly  Completed    qs007  ...
# 3569            Kamil Majchrzak  Completed    qs009  ...
# 3571           Hamad Medjedovic  Completed    qs013  ...
# 3769     Thiago Agustin Tirante  Completed    qs011  ...
#
#       p2_service_points_won p2_return_points_won p2_total_points_won  \
# 250                    0.67                 0.43                0.54
# 446                    0.69                 0.49                0.58
# 473                    0.76                 0.54                0.66
# 614                    0.80                 0.42                0.58
# 811                    0.62                 0.40                0.51
# 894                    0.76                 0.57                0.65
# 933                    0.79                 0.50                0.63
# 934                    0.71                 0.49                0.59
# 1066                   0.57                 0.42                0.51
# 1310                   0.54                 0.52                0.53
# 1479                   0.76                 0.48                0.62
# 1730                   0.80                 0.49                0.62
# 2003                   0.66                 0.49                0.58
# 2091                   0.52                 0.24                0.40
# 2175                   0.68                 0.40                0.52
# 2450                   0.63                 0.42                0.54
# 2490                   0.58                 0.48                0.53
# 2491                   0.71                 0.36                0.54
# 2560                   0.62                 0.27                0.45
# 2569                   0.59                 0.42                0.50
# 2570                   0.70                 0.39                0.55
# 2862                   0.76                 0.56                0.64
# 2913                   0.59                 0.29                0.43
# 2918                   0.65                 0.36                0.50
# 2921                   0.72                 0.48                0.59
# 3199                   0.94                 0.46                0.64
# 3393                   0.79                 0.34                0.54
# 3411                   0.78                 0.42                0.59
# 3427                   0.68                 0.29                0.48
# 3447                   0.63                 0.32                0.48
# 3491                   0.80                 0.41                0.58
# 3513                   0.79                 0.33                0.57
# 3524                   0.54                 0.36                0.44
# 3569                   0.97                 0.55                0.72
# 3571                   0.67                 0.43                0.54
# 3769                   0.67                 0.42                0.53
#
#      p2_max_speed  p2_1st_serve_average_speed p2_2nd_serve_average_speed  \
# 250           NaN                         NaN                        NaN
# 446           NaN                         NaN                        NaN
# 473           NaN                         NaN                        NaN
# 614           NaN                         NaN                        NaN
# 811           NaN                         NaN                        NaN
# 894           NaN                         NaN                        NaN
# 933           NaN                         NaN                        NaN
# 934           NaN                         NaN                        NaN
# 1066          NaN                         NaN                        NaN
# 1310          NaN                         NaN                        NaN
# 1479          NaN                         NaN                        NaN
# 1730          NaN                         NaN                        NaN
# 2003          NaN                         NaN                        NaN
# 2091          NaN                         NaN                        NaN
# 2175          NaN                         NaN                        NaN
# 2450          NaN                         NaN                        NaN
# 2490          NaN                         NaN                        NaN
# 2491          NaN                         NaN                        NaN
# 2560          NaN                         NaN                        NaN
# 2569          NaN                         NaN                        NaN
# 2570          NaN                         NaN                        NaN
# 2862          NaN                         NaN                        NaN
# 2913          NaN                         NaN                        NaN
# 2918          NaN                         NaN                        NaN
# 2921          NaN                         NaN                        NaN
# 3199          NaN                         NaN                        NaN
# 3393          NaN                         NaN                        NaN
# 3411          NaN                         NaN                        NaN
# 3427          NaN                         NaN                        NaN
# 3447          NaN                         NaN                        NaN
# 3491          NaN                         NaN                        NaN
# 3513          NaN                         NaN                        NaN
# 3524          NaN                         NaN                        NaN
# 3569          NaN                         NaN                        NaN
# 3571          NaN                         NaN                        NaN
# 3769          NaN                         NaN                        NaN
#
#      p2_break_point_opportunities p1_break_point_opportunities  \
# 250                           6.0                          5.0
# 446                          12.0                          3.0
# 473                           7.0                          3.0
# 614                           5.0                          3.0
# 811                           6.0                          7.0
# 894                          11.0                          0.0
# 933                          10.0                          1.0
# 934                          13.0                          4.0
# 1066                          8.0                         13.0
# 1310                         17.0                         14.0
# 1479                          5.0                          1.0
# 1730                         10.0                          0.0
# 2003                          7.0                          7.0
# 2091                          3.0                         13.0
# 2175                         21.0                          5.0
# 2450                          5.0                          9.0
# 2490                          8.0                          6.0
# 2491                          8.0                          2.0
# 2560                          3.0                          4.0
# 2569                         18.0                         10.0
# 2570                          3.0                          6.0
# 2862                          9.0                          0.0
# 2913                          8.0                          9.0
# 2918                          6.0                         10.0
# 2921                         14.0                          1.0
# 3199                          8.0                          0.0
# 3393                          6.0                          0.0
# 3411                          4.0                          4.0
# 3427                          2.0                          6.0
# 3447                          6.0                          9.0
# 3491                          6.0                          0.0
# 3513                          5.0                          4.0
# 3524                          7.0                          4.0
# 3569                          7.0                          0.0
# 3571                         11.0                          5.0
# 3769                          7.0                          3.0
#
#      p1_net_points_played  p2_net_points_played
# 250                  19.0                  18.0
# 446                   0.0                   0.0
# 473                   0.0                   0.0
# 614                   0.0                   0.0
# 811                   9.0                  10.0
# 894                   4.0                   9.0
# 933                   4.0                  11.0
# 934                  10.0                   4.0
# 1066                 27.0                  29.0
# 1310                  9.0                  12.0
# 1479                  7.0                   9.0
# 1730                  5.0                   6.0
# 2003                  0.0                   0.0
# 2091                  2.0                   4.0
# 2175                 13.0                  16.0
# 2450                 27.0                  40.0
# 2490                 11.0                  10.0
# 2491                  9.0                  13.0
# 2560                 16.0                  10.0
# 2569                 40.0                  47.0
# 2570                  6.0                   9.0
# 2862                 17.0                   8.0
# 2913                  8.0                  10.0
# 2918                 44.0                  24.0
# 2921                  7.0                  13.0
# 3199                  3.0                   1.0
# 3393                 21.0                  12.0
# 3411                 29.0                   8.0
# 3427                 33.0                  13.0
# 3447                 46.0                  21.0
# 3491                 12.0                   9.0
# 3513                  9.0                  19.0
# 3524                  6.0                   7.0
# 3569                 12.0                   5.0
# 3571                 21.0                  19.0
# 3769                  0.0                   0.0
#
# [36 rows x 78 columns]

# %%
merged_tourn_stat_trial[(merged_tourn_stat_trial['p1_id'].isna()) | merged_tourn_stat_trial['p2_id'].isna()]
# Out:
#      match_date          player_1           player_2        duration  \
# 167  2024-12-29         G. Diallo         K. Lung Ng 0 days 01:51:53
# 250  2025-01-05    A. Klintcharov           S. Nagal 0 days 01:54:40
# 425  2025-01-07       Y. Uchiyama  A. Daniel Vallejo             NaT
# 446  2025-01-07         C. Hewitt    N. Basilashvili             NaT
# 473  2025-01-06  T. van Rijthoven             J. Kym             NaT
# ...         ...               ...                ...             ...
# 3569 2024-10-20           R. Ymer       K. Majchrzak 0 days 00:49:00
# 3571 2024-10-20        A. Reymond      H. Medjedovic 0 days 01:35:00
# 3769 2024-11-09     M. Maksimovic         T. Tirante 0 days 01:47:00
# 3794 2024-11-09          Q. Halys     T. Papamalamis 0 days 01:04:00
# 3805 2024-11-09        J. de Jong     T. Papamalamis 0 days 01:52:00
#
#                match_round player_1_scores player_2_scores  \
# 167   1st Round Qualifying             7 6          6(2) 2
# 250   1st Round Qualifying           6 3 1           1 6 6
# 425   2nd Round Qualifying           4 6 6           6 3 4
# 446   1st Round Qualifying             1 4             6 6
# 473   1st Round Qualifying             0 3             6 6
# ...                    ...             ...             ...
# 3569  1st Round Qualifying             1 1             6 6
# 3571  1st Round Qualifying          6(4) 5             7 7
# 3769  1st Round Qualifying          6(7) 3             7 6
# 3794           Round of 32             6 6             3 1
# 3805  1st Round Qualifying             6 6             2 3
#
#                       winner     result match_id  ...  p2_service_points_won  \
# 167           Gabriel Diallo  Completed    qs010  ...                   0.55
# 250              Sumit Nagal  Completed    qs009  ...                   0.67
# 425        Yasutaka Uchiyama  Completed    qs052  ...                   0.59
# 446     Nikoloz Basilashvili  Completed    qs082  ...                   0.69
# 473               Jerome Kym  Completed    qs115  ...                   0.76
# ...                      ...        ...      ...  ...                    ...
# 3569         Kamil Majchrzak  Completed    qs009  ...                   0.97
# 3571        Hamad Medjedovic  Completed    qs013  ...                   0.67
# 3769  Thiago Agustin Tirante  Completed    qs011  ...                   0.67
# 3794           Quentin Halys  Completed    ms029  ...                   0.47
# 3805          Jesper de Jong  Completed    qs014  ...                   0.52
#
#      p2_return_points_won p2_total_points_won p2_max_speed  \
# 167                  0.25                0.43          NaN
# 250                  0.43                0.54          NaN
# 425                  0.38                0.48          NaN
# 446                  0.49                0.58          NaN
# 473                  0.54                0.66          NaN
# ...                   ...                 ...          ...
# 3569                 0.55                0.72          NaN
# 3571                 0.43                0.54          NaN
# 3769                 0.42                0.53          NaN
# 3794                 0.14                0.34          NaN
# 3805                 0.23                0.42          NaN
#
#       p2_1st_serve_average_speed p2_2nd_serve_average_speed  \
# 167                          NaN                        NaN
# 250                          NaN                        NaN
# 425                          NaN                        NaN
# 446                          NaN                        NaN
# 473                          NaN                        NaN
# ...                          ...                        ...
# 3569                         NaN                        NaN
# 3571                         NaN                        NaN
# 3769                         NaN                        NaN
# 3794                         NaN                        NaN
# 3805                         NaN                        NaN
#
#      p2_break_point_opportunities p1_break_point_opportunities  \
# 167                           0.0                          7.0
# 250                           6.0                          5.0
# 425                           9.0                          8.0
# 446                          12.0                          3.0
# 473                           7.0                          3.0
# ...                           ...                          ...
# 3569                          7.0                          0.0
# 3571                         11.0                          5.0
# 3769                          7.0                          3.0
# 3794                          0.0                         10.0
# 3805                          0.0                         10.0
#
#      p1_net_points_played  p2_net_points_played
# 167                  12.0                   9.0
# 250                  19.0                  18.0
# 425                   0.0                   0.0
# 446                   0.0                   0.0
# 473                   0.0                   0.0
# ...                   ...                   ...
# 3569                 12.0                   5.0
# 3571                 21.0                  19.0
# 3769                  0.0                   0.0
# 3794                 15.0                   1.0
# 3805                 22.0                  12.0
#
# [72 rows x 78 columns]

# %%
merged_tourn_stat_trial.to_csv('/Users/samueleferrucci/Documents/Coding/Projects/Tennis ML/data/clean/merged_matches.csv', sep=',', columns=merged_tourn_stat_trial.columns, index=False)
merged_tourn_stat_trial.to_csv('s3://matchedge-pipeline/data/clean/merged_matches.csv', sep=',', columns=merged_tourn_stat_trial.columns, index=False)
